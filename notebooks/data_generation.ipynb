# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from instance_generation import generate_instances

filename = "E11B.txt"
n_instances = 1000
n_types = 60
seed = 43

generate_instances(filename, n_instances, n_types, seed)

# %%
from data_generation import run_instances_parallel

instance_filename="E6A.txt"
w=8
max_workers=60

run_instances_parallel(instance_filename, w, max_workers, 1)
# Out:
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E4B

# %%
from data_generation import run_instances_parallel

filenames = ["E6A.txt", "E6B.txt", "E7A.txt", "E7B.txt"]
w=8
max_workers=60

for filename in filenames:
    run_instances_parallel(filename, w, max_workers, 1)

# %%
from data_generation import generate_data_from_folder

folder_path = "E4A"

generate_data_from_folder(folder_path)
# Out:
# Datos guardados en: /home/oscar/CLP-Framework/data/E4N.data

# %%
from data_generation import generate_data_from_folder

folders = ["E6A", "E6B", "E7A", "E7B"]

for folder in folders:
    generate_data_from_folder(folder)
# Out:
# Datos guardados en: /home/oscar/CLP-Framework/data/E6A.data
# Datos guardados en: /home/oscar/CLP-Framework/data/E6B.data
# Datos guardados en: /home/oscar/CLP-Framework/data/E7A.data
# Datos guardados en: /home/oscar/CLP-Framework/data/E7B.data

# %%
from data_preprocessing import load_data

filename = "E4A.data"

dataset = load_data(filename)

print("Block features:", dataset.block_features.shape)
print("Action blocks:", dataset.action_blocks.shape)
print("Action features:", dataset.action_features.shape)
print("Placed blocks:", dataset.placed_blocks.shape)
print("Placed features:", dataset.placed_features.shape)
print("Space features:", dataset.space_features.shape)
print("Y:", dataset.Y.shape)
# Out:
# Block features: (11142, 10000, 8)
# Action blocks: (11142, 64)
# Action features: (11142, 64, 2)
# Placed blocks: (11142, 64)
# Placed features: (11142, 64, 4)
# Space features: (11142, 6)
# Y: (11142, 64)

# %%
from data_preprocessing import generate_datasets

filenames = ["E4O.data", "E4P.data", "E4Q.data"]
basename = "E4O-Q"
cuts = [1, 1, 8, 64]
max_size = 5000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E4O.data
# Procesando archivo: E4P.data
# Procesando archivo: E4Q.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4O-Q_1-1.data (Tamaño 5000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4O-Q_2-8.data (Tamaño 5000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4O-Q_9-64.data (Tamaño 2295)

# %%
from data_preprocessing import generate_datasets

base = "E7"
filenames = [f"{base}A.data", f"{base}B.data"]
basename = base
cuts = [1, 1, 8, 64]
max_size = 1200

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E7A.data
# Procesando archivo: E7B.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E7_1-1.data (Tamaño 1200)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E7_2-8.data (Tamaño 1200)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E7_9-64.data (Tamaño 1200)

# %%
from data_preprocessing import generate_datasets

filenames = ["datasets/E1_9-64.data", "datasets/E2_9-64.data", "datasets/E3_9-64.data", "datasets/E4_9-64.data", "datasets/E5_9-64.data", "datasets/E6_9-64.data", "datasets/E7_9-64.data", "datasets/E8_9-64.data", "datasets/E9_9-64.data", "datasets/E10_9-64.data"]
basename = "E"
cuts = [9, 64]
max_size = 20000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: datasets/E1_9-64.data
# Procesando archivo: datasets/E2_9-64.data
# Procesando archivo: datasets/E3_9-64.data
# Procesando archivo: datasets/E4_9-64.data
# Procesando archivo: datasets/E5_9-64.data
# Procesando archivo: datasets/E6_9-64.data
# Procesando archivo: datasets/E7_9-64.data
# Procesando archivo: datasets/E8_9-64.data
# Procesando archivo: datasets/E9_9-64.data
# Procesando archivo: datasets/E10_9-64.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E_9-64.data (Tamaño 12000)
