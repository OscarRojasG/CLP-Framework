# %%
# %load_ext autoreload
# %autoreload 2

# %%
from instance_generation import generate_instances

filename = "E15A.txt"
n_instances = 1000
n_types = 100
seed = 42

generate_instances(filename, n_instances, n_types, seed)

# %%
from instance_generation import generate_instances

for i in range(9, 10):
    filename = f"V{i}.txt"
    n_instances = 1000
    n_types = 40
    seed = 41
    generate_instances(filename, n_instances, n_types, seed)

# %%
from data_generation import run_instances_parallel

filenames = [f"V{i}.txt" for i in range(9, 16)]
w=8
max_workers = 50
min_fr = 0.98

for filename in filenames:
    run_instances_parallel(filename, w, max_workers, min_fr)
# Out:
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/V9
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/V10
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/V11
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/V12
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/V13
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/V14
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/V15

# %%
from data_generation import generate_data_from_folder

folders = [f"V{i}" for i in range(8,16)]

for folder in folders:
    generate_data_from_folder(folder)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CLP-Framework/data/V8.data
# Datos guardados en: /home/oscar/Escritorio/CLP-Framework/data/V9.data
# Datos guardados en: /home/oscar/Escritorio/CLP-Framework/data/V10.data
# Datos guardados en: /home/oscar/Escritorio/CLP-Framework/data/V11.data
# Datos guardados en: /home/oscar/Escritorio/CLP-Framework/data/V12.data
# Datos guardados en: /home/oscar/Escritorio/CLP-Framework/data/V13.data
# Datos guardados en: /home/oscar/Escritorio/CLP-Framework/data/V14.data
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 6
#       3 folders = [f"V{i}" for i in range(8,16)]
#       5 for folder in folders:
# ----> 6     generate_data_from_folder(folder)
#
# File ~/Escritorio/CLP-Framework/src/data_generation.py:230, in generate_data_from_folder(folder_path, label_type, filename)
#     228 # Guardar los datos
#     229 with h5py.File(output_path, "w") as f:
# --> 230     f.create_dataset("block_features", data=np.array(block_features_all, dtype=np.float32))
#     231     f.create_dataset("action_blocks", data=np.array(action_blocks_all, dtype=np.int32))
#     232     f.create_dataset("action_features", data=np.array(action_features_all, dtype=np.float32))
#
# File ~/Escritorio/CLP-Framework/.venv/lib/python3.12/site-packages/h5py/_hl/group.py:240, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     237         parent_path, name = name.rsplit(b'/', 1)
#     238         group = self.require_group(parent_path)
# --> 240 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     241 dset = dataset.Dataset(dsid)
#     242 return dset
#
# File ~/Escritorio/CLP-Framework/.venv/lib/python3.12/site-packages/h5py/_hl/dataset.py:192, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0, fill_time)
#     189 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     191 if (data is not None) and (not isinstance(data, Empty)):
# --> 192     dset_id.write(h5s.ALL, h5s.ALL, data)
#     194 return dset_id
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:305, in h5py.h5d.DatasetID.write()
#
# File h5py/_proxy.pyx:122, in h5py._proxy.dset_rw()
#
# OSError: [Errno 28] Can't synchronously write data (file write failed: time = Wed Apr  1 00:23:48 2026
# , filename = '/home/oscar/Escritorio/CLP-Framework/data/V15.data', file descriptor = 73, errno = 28, error message = 'No space left on device', buf = 0x794b3267a810, total write size = 4022222336, bytes this sub-write = 4022222336, offset = 4521459712)

# %%
from data_preprocessing import load_data

filename = "E8-1.data"

dataset = load_data(filename)

print("Block features:", dataset.block_features.shape)
print("Action blocks:", dataset.action_blocks.shape)
print("Action features:", dataset.action_features.shape)
print("Placed blocks:", dataset.placed_blocks.shape)
print("Placed features:", dataset.placed_features.shape)
print("Space features:", dataset.space_features.shape)
print("Y:", dataset.Y.shape)
print("Label type:", dataset.label_type)
# Out:
# Block features: (17159, 10000, 8)
# Action blocks: (17159, 64)
# Action features: (17159, 64, 2)
# Placed blocks: (17159, 64)
# Placed features: (17159, 64, 4)
# Space features: (17159, 6)
# Y: (17159, 64)
# Label type: 1

# %%
from data_preprocessing import generate_datasets

filenames = [f"E8-{i}.data" for i in range(1, 21)]
basename = "E8"
cuts = [1, 1, 8, 64]
max_size = 16400

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando corte: [1, 1]
# Dataset guardado en: /home/oscar/Escritorio/CLP-Framework/data/datasets/E8_1-1.data (Tamaño 16400)
# Procesando corte: [2, 8]
# Dataset guardado en: /home/oscar/Escritorio/CLP-Framework/data/datasets/E8_2-8.data (Tamaño 16400)
# Procesando corte: [9, 64]
# Dataset guardado en: /home/oscar/Escritorio/CLP-Framework/data/datasets/E8_9-64.data (Tamaño 16400)
