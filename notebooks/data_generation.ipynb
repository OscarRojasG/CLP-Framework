# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from instance_generation import generate_instances

filename = "E11B.txt"
n_instances = 1000
n_types = 60
seed = 43

generate_instances(filename, n_instances, n_types, seed)

# %%
from data_generation import run_instances_parallel

instance_filename="E6A.txt"
w=8
max_workers=60

run_instances_parallel(instance_filename, w, max_workers, 1)
# Out:
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E4B

# %%
from data_generation import run_instances_parallel

filenames = ["E8B.txt", "E9A.txt", "E9B.txt", "E10A.txt", "E10B.txt", "E11A.txt", "E11B.txt"]
w=8
max_workers=60

for filename in filenames:
    run_instances_parallel(filename, w, max_workers, 0.98)
# Out:
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E8A
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 8
#       5 max_workers=60
#       7 for filename in filenames:
# ----> 8     run_instances_parallel(filename, w, max_workers, 0.98)
#
# File /home/oscar/CLP-Framework/src/data_generation.py:96, in run_instances_parallel(instance_filename, w, max_workers, min_fr)
#      93 os.makedirs(OUTPUT_FOLDER, exist_ok=True)
#      95 # Ejecutar las instancias en paralelo
# ---> 96 with ThreadPoolExecutor(max_workers=max_workers) as executor:
#      97     for i in range(num_instances):
#      98         executor.submit(run_instance, instance_filename, i, w, base_folder, min_fr)
#
# File /usr/lib/python3.13/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File /usr/lib/python3.13/concurrent/futures/thread.py:239, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 if wait:
#     238     for t in self._threads:
# --> 239         t.join()
#
# File /usr/lib/python3.13/threading.py:1094, in Thread.join(self, timeout)
#    1091 if timeout is not None:
#    1092     timeout = max(timeout, 0)
# -> 1094 self._handle.join(timeout)
#
# KeyboardInterrupt:

# %%
from data_generation import generate_data_from_folder

folder_path = "E4A"

generate_data_from_folder(folder_path)
# Out:
# Datos guardados en: /home/oscar/CLP-Framework/data/E4N.data

# %%
from data_generation import generate_data_from_folder

folders = ["E4A", "E4B", "E4C", "E4D", "E4E", "E4F", "E4G", "E4H", "E4I", "E4J", "E4K", "E4L", "E4M", "E4N", "E4O", "E4P", "E4Q"]

for folder in folders:
    generate_data_from_folder(folder)

# %%
from data_preprocessing import load_data

filename = "E4A.data"

dataset = load_data(filename)

print("Block features:", dataset.block_features.shape)
print("Action blocks:", dataset.action_blocks.shape)
print("Action features:", dataset.action_features.shape)
print("Placed blocks:", dataset.placed_blocks.shape)
print("Placed features:", dataset.placed_features.shape)
print("Space features:", dataset.space_features.shape)
print("Y:", dataset.Y.shape)
# Out:
# Block features: (8854, 10000, 8)
# Action blocks: (8854, 64)
# Action features: (8854, 64, 5)
# Placed blocks: (8854, 64)
# Placed features: (8854, 64, 4)
# Space features: (8854, 6)
# Y: (8854, 64)

# %%
from data_preprocessing import generate_datasets

filenames = ["E4O.data", "E4P.data", "E4Q.data"]
basename = "E4O-Q"
cuts = [1, 1, 8, 64]
max_size = 5000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E4O.data
# Procesando archivo: E4P.data
# Procesando archivo: E4Q.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4O-Q_1-1.data (Tamaño 5000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4O-Q_2-8.data (Tamaño 5000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4O-Q_9-64.data (Tamaño 2295)

# %%
from data_preprocessing import generate_datasets

filenames = ["datasets/E4A-F_9-64.data", "datasets/E4G-L_9-64.data", "datasets/E4M-Q_9-64.data"]
basename = "E4A-Q"
cuts = [9, 64]
max_size = 12500

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: datasets/E4A-F_9-64.data
# Procesando archivo: datasets/E4G-L_9-64.data
# Procesando archivo: datasets/E4M-Q_9-64.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4A-Q_9-64.data (Tamaño 12500)
