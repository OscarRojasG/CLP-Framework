# %%
# %load_ext autoreload
# %autoreload 2

# %%
from instance_generation import generate_instances

filename = "E4A.txt"
n_instances = 1000
n_types = 10
seed = 42

generate_instances(filename, n_instances, n_types, seed)

# %%
from data_generation import run_instances_parallel

instance_filename="E4A.txt"
w=8
max_workers=32

run_instances_parallel(instance_filename, w, max_workers)
# Out:
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E4A

# %%
from data_generation import generate_data_from_folder

folder_path = "E4A"

generate_data_from_folder(folder_path)
# Out:
# Datos guardados en: /home/oscar/CLP-Framework/data/E4A.data

# %%
from data_preprocessing import load_data

filename = "E4A.data"

dataset = load_data(filename)

print("Block features:", dataset.block_features.shape)
print("Action blocks:", dataset.action_blocks.shape)
print("Action features:", dataset.action_features.shape)
print("Placed blocks:", dataset.placed_blocks.shape)
print("Placed features:", dataset.placed_features.shape)
print("Y:", dataset.Y.shape)
# Out:
# Block features: (8854, 10000, 8)
# Action blocks: (8854, 64)
# Action features: (8854, 64, 5)
# Placed blocks: (8854, 64)
# Placed features: (8854, 64, 4)
# Y: (8854, 64)

# %%
from data_preprocessing import generate_datasets

filenames = ["E4A.data", "E4B.data", "E4C.data", "E4D.data", "E4E.data"]
basename = "E41"
cuts = [1, 1, 8, 64]
max_size = 4000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E4A.data
# Procesando archivo: E4B.data
# Procesando archivo: E4C.data
# Procesando archivo: E4D.data
# Procesando archivo: E4E.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E41_1-1.data (Tamaño 4000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E41_2-8.data (Tamaño 4000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E41_9-64.data (Tamaño 3731)

# %%
from data_preprocessing import generate_datasets

filenames = ["E4F.data", "E4G.data", "E4H.data", "E4I.data", "E4J.data"]
basename = "E42"
cuts = [1, 1, 8, 64]
max_size = 4000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E4F.data
# Procesando archivo: E4G.data
# Procesando archivo: E4H.data
# Procesando archivo: E4I.data
# Procesando archivo: E4J.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E42_1-1.data (Tamaño 4000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E42_2-8.data (Tamaño 4000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E42_9-64.data (Tamaño 3743)

# %%
from data_preprocessing import generate_datasets

filenames = ["E4K.data", "E4L.data", "E4M.data", "E4N.data", "E4O.data"]
basename = "E43"
cuts = [1, 1, 8, 64]
max_size = 4000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E4K.data
# Procesando archivo: E4L.data
# Procesando archivo: E4M.data
# Procesando archivo: E4N.data
# Procesando archivo: E4O.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E43_1-1.data (Tamaño 4000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E43_2-8.data (Tamaño 4000)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E43_9-64.data (Tamaño 3791)

# %%
from data_preprocessing import generate_datasets

filenames = ["datasets/E41_1-1.data", "datasets/E42_1-1.data", "datasets/E43_1-1.data"]
basename = "E4"
cuts = [1, 1]
max_size = 10000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: datasets/E41_1-1.data
# Procesando archivo: datasets/E42_1-1.data
# Procesando archivo: datasets/E43_1-1.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E4_1-1.data (Tamaño 10000)
