# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.instance_generator import *

gen_instances("E1.txt", n_instances=1000, n_types=3, seed=42)

# %%
from src.data_generator import run_instance

run_instance(file_path="E4F.txt", i=0, w=8)

# %%
from src.data_generator import run_file_instances_parallel

run_file_instances_parallel(file_path="E4A.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4I.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4J.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4D.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4E.txt", w=8, max_workers=32)

# %%
from src.data_generator import generate_data_from_folder

generate_data_from_folder("E4A.out")
#generate_data_from_folder("E4I.out")
#generate_data_from_folder("E4J.out")
#generate_data_from_folder("E4D.out")
#generate_data_from_folder("E4E.out")
# Out:
# Datos guardados en: data/E4A.data

# %%
import gc
gc.collect()
# Out:
# 0

# %%
from src.data_generator import join_data_files

join_data_files(["E4F.data", "E4G.data", "E4H.data", "E4I.data", "E4J.data"], "E4.data")
# Out:
# Datos combinados guardados en: data/E4.data

# %%
from src.data_preprocessing import generate_datasets

generate_datasets("E4A.data", [1, 8, 64], max_size=4000)
# Out:
# Procesando archivo: E4A.data
# Dataset guardado en: data/datasets/E4A_1-1.data (Tamaño 4000)
# Dataset guardado en: data/datasets/E4A_2-8.data (Tamaño 3689)
# Dataset guardado en: data/datasets/E4A_9-64.data (Tamaño 763)

# %%
from importlib import reload
import src.data_generator
reload(src.data_generator)
# Out:
# <module 'src.data_generator' from '/home/oscar/CLP-Framework/src/data_generator.py'>

# %%
from src.data_generator import generate_train_data

a = generate_train_data("outputs/E4A.out/E4A-1.out")
a[1][0].tolist()
# Out:
# [[9280.0,
#   0.40602826,
#   0.02173913,
#   0.060905189,
#   0.85087361,
#   0.85087361,
#   0.85087361],
#  [6215.0,
#   0.31390347,
#   0.026315789,
#   0.060905189,
#   0.82179032,
#   0.82179032,
#   0.82179032],
#  [9276.0,
#   0.31274094,
#   0.023255814,
#   0.060905189,
#   0.82179032,
#   0.82179032,
#   0.82179032],
#  [9453.0,
#   0.59707441,
#   0.018181818,
#   0.11545064,
#   0.68359422,
#   0.68359422,
#   0.68359422],
#  [9685.0,
#   0.26867418,
#   0.027027027,
#   0.018181818,
#   0.79626766,
#   0.79626766,
#   0.79626766],
#  [9406.0,
#   0.50732917,
#   0.022727273,
#   0.039797113,
#   0.6884055,
#   0.6884055,
#   0.6884055],
#  [9899.0,
#   0.25251884,
#   0.037037037,
#   0.056281701,
#   0.79635866,
#   0.79635866,
#   0.79635866],
#  [9232.0,
#   0.52582279,
#   0.019230769,
#   0.12738978,
#   0.69186843,
#   0.69186843,
#   0.69186843],
#  [9341.0,
#   0.51326231,
#   0.02173913,
#   0.012875536,
#   0.66100817,
#   0.66100817,
#   0.66100817],
#  [9254.0,
#   0.50467557,
#   0.023255814,
#   0.017167382,
#   0.65855991,
#   0.65855991,
#   0.65855991],
#  [9915.0,
#   0.48528124,
#   0.020833333,
#   0.034334764,
#   0.66943155,
#   0.66943155,
#   0.66943155],
#  [6260.0,
#   0.43685856,
#   0.027027027,
#   0.012875536,
#   0.66417679,
#   0.66417679,
#   0.66417679],
#  [9411.0,
#   0.41405136,
#   0.020833333,
#   0.031447522,
#   0.67957095,
#   0.67957095,
#   0.67957095],
#  [9618.0,
#   0.47281594,
#   0.018181818,
#   0.10204838,
#   0.67444167,
#   0.67444167,
#   0.67444167],
#  [9504.0,
#   0.46078727,
#   0.019607843,
#   0.10204838,
#   0.6732963,
#   0.6732963,
#   0.6732963],
#  [9779.0,
#   0.44791732,
#   0.022222222,
#   0.09758096,
#   0.67213439,
#   0.67213439,
#   0.67213439],
#  [9162.0, 0.41451112, 0.018181818, 0.0, 0.67454835, 0.67454835, 0.67454835],
#  [9555.0,
#   0.43633778,
#   0.025641026,
#   0.10204838,
#   0.67086744,
#   0.67086744,
#   0.67086744],
#  [9460.0, 0.45659978, 0.02, 0.11545064, 0.67255267, 0.67255267, 0.67255267],
#  [9461.0, 0.45659978, 0.02, 0.11545064, 0.67226564, 0.67226564, 0.67226564],
#  [9561.0,
#   0.44913209,
#   0.018867925,
#   0.077272727,
#   0.66957945,
#   0.66957945,
#   0.66957945],
#  [9580.0,
#   0.45880127,
#   0.01754386,
#   0.11381194,
#   0.67508415,
#   0.67508415,
#   0.67508415],
#  [9405.0,
#   0.38148192,
#   0.035714286,
#   0.031447522,
#   0.66653681,
#   0.66653681,
#   0.66653681],
#  [9837.0,
#   0.4525663,
#   0.01754386,
#   0.11773313,
#   0.67529701,
#   0.67529701,
#   0.67529701],
#  [9565.0, 0.43627191, 0.02, 0.10456496, 0.67384429, 0.67384429, 0.67384429],
#  [9566.0, 0.43528346, 0.02, 0.10456496, 0.67384429, 0.67384429, 0.67384429],
#  [7546.0,
#   0.21398077,
#   0.028571429,
#   0.030042918,
#   0.77106969,
#   0.77106969,
#   0.77106969],
#  [9564.0,
#   0.43056835,
#   0.020833333,
#   0.11773313,
#   0.67285494,
#   0.67285494,
#   0.67285494],
#  [9578.0,
#   0.42047736,
#   0.023255814,
#   0.11381194,
#   0.67122392,
#   0.67122392,
#   0.67122392],
#  [9601.0, 0.42913902, 0.02, 0.11773313, 0.67285494, 0.67285494, 0.67285494],
#  [9227.0,
#   0.3875365,
#   0.019230769,
#   0.021634803,
#   0.6720154,
#   0.6720154,
#   0.6720154],
#  [6169.0,
#   0.39296369,
#   0.027777778,
#   0.017167382,
#   0.65227766,
#   0.65227766,
#   0.65227766],
#  [6785.0,
#   0.39094791,
#   0.028571429,
#   0.017167382,
#   0.65213742,
#   0.65213742,
#   0.65213742],
#  [6423.0,
#   0.38198355,
#   0.027027027,
#   0.034451814,
#   0.66053244,
#   0.66053244,
#   0.66053244],
#  [9293.0,
#   0.39611248,
#   0.02173913,
#   0.098712446,
#   0.6729786,
#   0.6729786,
#   0.6729786],
#  [6684.0, 0.19706091, 0.04, 0.018181818, 0.75852142, 0.75852142, 0.75852142],
#  [7175.0,
#   0.36222432,
#   0.03125,
#   0.017167382,
#   0.65775614,
#   0.65775614,
#   0.65775614],
#  [7178.0,
#   0.36222432,
#   0.03125,
#   0.017167382,
#   0.65762303,
#   0.65762303,
#   0.65762303],
#  [9279.0,
#   0.38448701,
#   0.023255814,
#   0.052087398,
#   0.66340787,
#   0.66340787,
#   0.66340787],
#  [9976.0,
#   0.4116391,
#   0.019230769,
#   0.1265119,
#   0.67073438,
#   0.67073438,
#   0.67073438],
#  [6140.0, 0.36573622, 0.03125, 0.12738978, 0.67444179, 0.67444179, 0.67444179],
#  [9706.0,
#   0.39434197,
#   0.02173913,
#   0.017167382,
#   0.65117851,
#   0.65117851,
#   0.65117851],
#  [9185.0,
#   0.38344851,
#   0.018867925,
#   0.043269606,
#   0.66427723,
#   0.66427723,
#   0.66427723],
#  [9184.0,
#   0.38344851,
#   0.018867925,
#   0.043269606,
#   0.6641338,
#   0.6641338,
#   0.6641338],
#  [9730.0, 0.39979847, 0.023255814, 0.0, 0.6430812, 0.6430812, 0.6430812],
#  [9535.0,
#   0.37453394,
#   0.022727273,
#   0.065606711,
#   0.66547181,
#   0.66547181,
#   0.66547181],
#  [7544.0, 0.39060075, 0.025, 0.030042918, 0.64917115, 0.64917115, 0.64917115],
#  [9579.0,
#   0.39782782,
#   0.019607843,
#   0.11381194,
#   0.66848282,
#   0.66848282,
#   0.66848282],
#  [6261.0,
#   0.34958089,
#   0.032258065,
#   0.021459227,
#   0.65365652,
#   0.65365652,
#   0.65365652],
#  [9835.0,
#   0.37251118,
#   0.026315789,
#   0.11773313,
#   0.66579254,
#   0.66579254,
#   0.66579254],
#  [9536.0,
#   0.37410762,
#   0.019607843,
#   0.069722981,
#   0.66596096,
#   0.66596096,
#   0.66596096],
#  [6386.0,
#   0.31887654,
#   0.041666667,
#   0.031447522,
#   0.66019336,
#   0.66019336,
#   0.66019336],
#  [9834.0, 0.37108185, 0.025, 0.11773313, 0.66579254, 0.66579254, 0.66579254],
#  [6292.0,
#   0.36394119,
#   0.041666667,
#   0.017167382,
#   0.63297074,
#   0.63297074,
#   0.63297074],
#  [6293.0,
#   0.36394119,
#   0.041666667,
#   0.017167382,
#   0.6329022,
#   0.6329022,
#   0.6329022],
#  [9526.0,
#   0.3649075,
#   0.019230769,
#   0.02590714,
#   0.65841594,
#   0.65841594,
#   0.65841594],
#  [9409.0,
#   0.40168178,
#   0.022727273,
#   0.031695316,
#   0.63803746,
#   0.63803746,
#   0.63803746],
#  [9379.0,
#   0.34089856,
#   0.021276596,
#   0.022727273,
#   0.66522061,
#   0.66522061,
#   0.66522061],
#  [9743.0,
#   0.39114093,
#   0.018181818,
#   0.003407155,
#   0.64268097,
#   0.64268097,
#   0.64268097],
#  [6280.0,
#   0.36251186,
#   0.038461538,
#   0.017167382,
#   0.6329022,
#   0.6329022,
#   0.6329022],
#  [4923.0,
#   0.1709892,
#   0.071428571,
#   0.034334764,
#   0.74279034,
#   0.74279034,
#   0.74279034],
#  [7765.0,
#   0.36223109,
#   0.035714286,
#   0.017167382,
#   0.6329022,
#   0.6329022,
#   0.6329022],
#  [6124.0,
#   0.31390347,
#   0.026315789,
#   0.031818182,
#   0.66565971,
#   0.66565971,
#   0.66565971],
#  [9729.0, 0.35373607, 0.025641026, 0.0, 0.64090103, 0.64090103, 0.64090103]]
