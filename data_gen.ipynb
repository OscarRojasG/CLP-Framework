# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.instance_generator import *

gen_instances("E4F.txt", n_instances=1000, n_types=10, seed=47)

# %%
from src.data_generator import run_instance

run_instance(file_path="E4F.txt", i=0, w=8)

# %%
from src.data_generator import run_file_instances_parallel

run_file_instances_parallel(file_path="E4F.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4B.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4C.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4D.txt", w=8, max_workers=32)
#run_file_instances_parallel(file_path="E4E.txt", w=8, max_workers=32)

# %%
from src.data_generator import generate_data_from_folder

generate_data_from_folder("E4F.out")
#generate_data_from_folder("E4B.out")
#generate_data_from_folder("E4C.out")
#generate_data_from_folder("E4D.out")
#generate_data_from_folder("E4E.out")
# Out:
# Datos guardados en: data/E4F.data

# %%
from src.data_generator import join_data_files

join_data_files(["E4A.data", "E4B.data", "E4C.data", "E4D.data", "E4E.data"], "E4.data")
# Out:
# Datos combinados guardados en: data/E4.data

# %%
from src.data_preprocessing import generate_datasets

generate_datasets("E4F.data", [1, 8, 64], max_size=5000)
# Out:
# Procesando archivo: E4F.data
# Dataset guardado en: data/datasets/E4F_1-1.data (Tamaño 4327)
# Dataset guardado en: data/datasets/E4F_2-8.data (Tamaño 3616)
# Dataset guardado en: data/datasets/E4F_9-64.data (Tamaño 745)
