# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from instance_generation import generate_instances

filename = "E15A.txt"
n_instances = 1000
n_types = 100
seed = 42

generate_instances(filename, n_instances, n_types, seed)

# %%
from data_generation import run_instances_parallel

instance_filename="E6A.txt"
w=8
max_workers=60

run_instances_parallel(instance_filename, w, max_workers, 1)
# Out:
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E4B

# %%
from data_generation import run_instances_parallel

filenames = ["E13B.txt", "E14A.txt", "E14B.txt", "E15A.txt", "E15B.txt"]
w=8
max_workers=40

for filename in filenames:
    run_instances_parallel(filename, w, max_workers, 0.98)
# Out:
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E13B
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E14A
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E14B
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E15A
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E15B

# %%
from data_generation import generate_data_from_folder

folder_path = "E4A"

generate_data_from_folder(folder_path)
# Out:
# Datos guardados en: /home/oscar/CLP-Framework/data/E4N.data

# %%
from data_generation import generate_data_from_folder

folders = ["E11A", "E11B"]

for folder in folders:
    generate_data_from_folder(folder)
# Out:
# Datos guardados en: /home/oscar/CLP-Framework/data/E11A.data
# Datos guardados en: /home/oscar/CLP-Framework/data/E11B.data

# %%
from data_preprocessing import load_data

filename = "E4A.data"

dataset = load_data(filename)

print("Block features:", dataset.block_features.shape)
print("Action blocks:", dataset.action_blocks.shape)
print("Action features:", dataset.action_features.shape)
print("Placed blocks:", dataset.placed_blocks.shape)
print("Placed features:", dataset.placed_features.shape)
print("Space features:", dataset.space_features.shape)
print("Y:", dataset.Y.shape)
# Out:
# Block features: (11142, 10000, 8)
# Action blocks: (11142, 64)
# Action features: (11142, 64, 2)
# Placed blocks: (11142, 64)
# Placed features: (11142, 64, 4)
# Space features: (11142, 6)
# Y: (11142, 64)

# %%
from data_preprocessing import generate_datasets

filenames = ["E11A.data", "E11B.data"]
basename = "E4O-Q"
cuts = [1, 1, 8, 64]
max_size = 5000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E11A.data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 8
#       5 cuts = [1, 1, 8, 64]
#       6 max_size = 5000
# ----> 8 generate_datasets(filenames, basename, cuts, max_size)
#
# File /home/oscar/CLP-Framework/src/data_preprocessing.py:66, in generate_datasets(filenames, basename, cuts, max_size, seed)
#      64 for filename in filenames:
#      65     print(f"Procesando archivo: {filename}")
# ---> 66     dataset_obj = load_data(filename)
#      68     for i in range(len(dataset_obj)):
#      69         y_vector = dataset_obj.Y[i]
#
# File /home/oscar/CLP-Framework/src/data_preprocessing.py:132, in load_data(filepath)
#     131 def load_data(filepath):
# --> 132     return H5Dataset(DATA_FOLDER / filepath)
#
# File /home/oscar/CLP-Framework/src/data_preprocessing.py:13, in H5Dataset.__init__(self, file_path)
#      11 def __init__(self, file_path):
#      12     self.file_path = file_path
# ---> 13     self._open_file()
#      14     self.name = os.path.basename(file_path)
#
# File /home/oscar/CLP-Framework/src/data_preprocessing.py:17, in H5Dataset._open_file(self)
#      16 def _open_file(self):
# ---> 17     self.file = h5py.File(self.file_path, "r")
#      18     self.block_features = self.file["block_features"]
#      19     self.action_blocks = self.file["action_blocks"]
#
# File /home/oscar/CLP-Framework/.venv/lib/python3.13/site-packages/h5py/_hl/files.py:566, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     557     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     558                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     559                      alignment_threshold=alignment_threshold,
#     560                      alignment_interval=alignment_interval,
#     561                      meta_block_size=meta_block_size,
#     562                      **kwds)
#     563     fcpl = make_fcpl(track_order=track_order, track_times=track_times,
#     564                      fs_strategy=fs_strategy, fs_persist=fs_persist,
#     565                      fs_threshold=fs_threshold, fs_page_size=fs_page_size)
# --> 566     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     568 if isinstance(libver, tuple):
#     569     self._libver = libver
#
# File /home/oscar/CLP-Framework/.venv/lib/python3.13/site-packages/h5py/_hl/files.py:241, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     239     if swmr and swmr_support:
#     240         flags |= h5f.ACC_SWMR_READ
# --> 241     fid = h5f.open(name, flags, fapl=fapl)
#     242 elif mode == 'r+':
#     243     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:104, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/home/oscar/CLP-Framework/data/E11A.data', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
from data_preprocessing import generate_datasets

filenames = ["E12A.data", "E12B.data"]
basename = "E12"
cuts = [1, 1, 8, 64]
max_size = 1200

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: E12A.data
# Procesando archivo: E12B.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E12_1-1.data (Tamaño 1200)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E12_2-8.data (Tamaño 1200)
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E12_9-64.data (Tamaño 1200)

# %%
from data_preprocessing import generate_datasets

filenames = ["datasets/E1_1-1.data", "datasets/E2_1-1.data", "datasets/E3_1-1.data", "datasets/E4_1-1.data", "datasets/E5_1-1.data", "datasets/E6_1-1.data", "datasets/E7_1-1.data", "datasets/E8_1-1.data", "datasets/E9_1-1.data", "datasets/E10_1-1.data", "datasets/E11_1-1.data", "datasets/E12_1-1.data", "datasets/E13_1-1.data", "datasets/E14_1-1.data", "datasets/E15_1-1.data"]
basename = "E"
cuts = [1, 1]
max_size = 20000

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando archivo: datasets/E1_1-1.data
# Procesando archivo: datasets/E2_1-1.data
# Procesando archivo: datasets/E3_1-1.data
# Procesando archivo: datasets/E4_1-1.data
# Procesando archivo: datasets/E5_1-1.data
# Procesando archivo: datasets/E6_1-1.data
# Procesando archivo: datasets/E7_1-1.data
# Procesando archivo: datasets/E8_1-1.data
# Procesando archivo: datasets/E9_1-1.data
# Procesando archivo: datasets/E10_1-1.data
# Procesando archivo: datasets/E11_1-1.data
# Procesando archivo: datasets/E12_1-1.data
# Procesando archivo: datasets/E13_1-1.data
# Procesando archivo: datasets/E14_1-1.data
# Procesando archivo: datasets/E15_1-1.data
# Dataset guardado en: /home/oscar/CLP-Framework/data/datasets/E_1-1.data (Tamaño 18000)
