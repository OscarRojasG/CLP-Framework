# %%
# %load_ext autoreload
# %autoreload 2

# %%
from instance_generation import generate_instances

filename = "E15A.txt"
n_instances = 1000
n_types = 100
seed = 42

generate_instances(filename, n_instances, n_types, seed)

# %%
from instance_generation import generate_instances

for i in range(1, 21):
    filename = f"E8-{i}.txt"
    n_instances = 1000
    n_types = 30
    seed = 41 + i
    generate_instances(filename, n_instances, n_types, seed)

# %%
from data_generation import run_instances_parallel

instance_filename="E6A.txt"
w=8
max_workers=60

run_instances_parallel(instance_filename, w, max_workers, 1)
# Out:
# Salida guardada en: /home/oscar/CLP-Framework/outputs/E4B

# %%
from data_generation import run_instances_parallel

filenames = [f"E8-{i}.txt" for i in range(6,7)]
w=8
max_workers=50

for filename in filenames:
    run_instances_parallel(filename, w, max_workers, 0.98)
# Out:
# Progreso: 100.00% (1000/1000)
# Salida guardada en: /home/oscar/Escritorio/CLP-Framework/outputs/E8-6

# %%
from data_generation import run_instances_parallel

filenames = [f"E8-{i}.txt" for i in range(8,10)]
w=8
max_workers=50

for filename in filenames:
    run_instances_parallel(filename, w, max_workers, 0.98)

# %%
from data_generation import generate_data_from_folder

folder_path = "E4A"

generate_data_from_folder(folder_path)
# Out:
# Datos guardados en: /home/oscar/CLP-Framework/data/E4N.data

# %%
from data_generation import generate_data_from_folder

folders = [f"E8-{i}" for i in range(8,10)]

for folder in folders:
    generate_data_from_folder(folder)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 folders = [f"E8-{i}" for i in range(8,10)]
#       5 for folder in folders:
# ----> 6     generate_data_from_folder(folder)
#
# File ~/Escritorio/CLP-Framework/src/data_generation.py:204, in generate_data_from_folder(folder_path)
#     200 file_path = os.path.join(OUTPUT_FOLDER / folder_path, filename)
#     202 if os.path.isfile(file_path):  # Solo procesar archivos (no directorios)
#     203     # Generar los datos de entrenamiento
# --> 204     block_features, action_blocks, action_features, placed_blocks, placed_features, space_features, Y = generate_train_data(file_path)
#     206     # Agregar los datos del archivo actual a las listas generales
#     207     block_features_all.extend(block_features)
#
# File ~/Escritorio/CLP-Framework/src/data_generation.py:139, in generate_train_data(filename, min_actions, padding_blocks, padding_placed)
#     137 pad_len = max(0, padding_blocks - n)
#     138 if pad_len > 0:
# --> 139     block_features = np.pad(block_features, pad_width=((0, pad_len), (0, 0)), mode='constant', constant_values=-1)
#     141 np_block_features = []
#     142 np_action_blocks = []
#
# File ~/Escritorio/CLP-Framework/.venv/lib/python3.12/site-packages/numpy/lib/_arraypad_impl.py:792, in pad(array, pad_width, mode, **kwargs)
#     789     raise TypeError('`pad_width` must be of integral type.')
#     791 # Broadcast to shape (array.ndim, 2)
# --> 792 pad_width = _as_pairs(pad_width, array.ndim, as_index=True)
#     794 if callable(mode):
#     795     # Old behavior: Use user-supplied function with np.apply_along_axis
#     796     function = mode
#
# File ~/Escritorio/CLP-Framework/.venv/lib/python3.12/site-packages/numpy/lib/_arraypad_impl.py:535, in _as_pairs(x, ndim, as_index)
#     531     raise ValueError("index can't contain negative values")
#     533 # Converting the array with `tolist` seems to improve performance
#     534 # when iterating and indexing the result (see usage in `pad`)
# --> 535 return np.broadcast_to(x, (ndim, 2)).tolist()
#
# File ~/Escritorio/CLP-Framework/.venv/lib/python3.12/site-packages/numpy/lib/_stride_tricks_impl.py:443, in broadcast_to(array, shape, subok)
#     400 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     401 def broadcast_to(array, shape, subok=False):
#     402     """Broadcast an array to a new shape.
#     403
#     404     Parameters
#    (...)    441            [1, 2, 3]])
#     442     """
# --> 443     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~/Escritorio/CLP-Framework/.venv/lib/python3.12/site-packages/numpy/lib/_stride_tricks_impl.py:382, in _broadcast_to(array, shape, subok, readonly)
#     379     raise ValueError('all elements of broadcast shape must be non-'
#     380                      'negative')
#     381 extras = []
# --> 382 it = np.nditer(
#     383     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     384     op_flags=['readonly'], itershape=shape, order='C')
#     385 with it:
#     386     # never really has writebackifcopy semantics
#     387     broadcast = it.itviews[0]
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (2,2)  and requested shape (1,2)

# %%
from data_preprocessing import load_data

filename = "E8-1.data"

dataset = load_data(filename)

print("Block features:", dataset.block_features.shape)
print("Action blocks:", dataset.action_blocks.shape)
print("Action features:", dataset.action_features.shape)
print("Placed blocks:", dataset.placed_blocks.shape)
print("Placed features:", dataset.placed_features.shape)
print("Space features:", dataset.space_features.shape)
print("Y:", dataset.Y.shape)
# Out:
# Block features: (17159, 10000, 8)
# Action blocks: (17159, 64)
# Action features: (17159, 64, 2)
# Placed blocks: (17159, 64)
# Placed features: (17159, 64, 4)
# Space features: (17159, 6)
# Y: (17159, 64)

# %%
from data_preprocessing import generate_datasets

filenames = [f"E8-{i}.data" for i in range(1, 8)]
basename = "E8"
cuts = [1, 1, 8, 64]
max_size = 5800

generate_datasets(filenames, basename, cuts, max_size)
# Out:
# Procesando corte: [1, 1]
# Dataset guardado en: /home/oscar/Escritorio/CLP-Framework/data/datasets/E8_1-1.data (Tamaño 5800)
# Procesando corte: [2, 8]
# Dataset guardado en: /home/oscar/Escritorio/CLP-Framework/data/datasets/E8_2-8.data (Tamaño 5800)
# Procesando corte: [9, 64]
# Dataset guardado en: /home/oscar/Escritorio/CLP-Framework/data/datasets/E8_9-64.data (Tamaño 5800)
